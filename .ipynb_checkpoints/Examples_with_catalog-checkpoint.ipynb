# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %pylab inline
basePath= '/verafs/home/yjagvara/Illustris_Shapes_dc/data/shape_catalogs/TNG100-1_99_galaxy_f_disk_3ways_5.020000.dat'
f = open(basePath)
header = f.readline()
last_col_name = header.split(',')[-1]
names = (tuple(last_col_name.split()))

tp =  ( 'i4',) + ( 'f16',) *( len(names) - 1)
data=np.loadtxt(basePath,skiprows = 1,dtype={'names': names, 'formats': tp} )

import numpy.lib.recfunctions as rfn
import illustris_python as il
import scipy.stats as st
from pandas import *
import pandas as pd
import warnings

basePath2=  '/verafs/scratch/phy200017p/share/TNG100-1/output'
fields=['SubhaloMassInRadType','SubhaloGrNr','SubhaloStellarPhotometrics']
snapNum=99
subhalos=il.groupcat.loadSubhalos(basePath2,snapNum,fields=fields)
mass=subhalos['SubhaloMassInRadType'][:,4]*10**10
g_r=subhalos['SubhaloStellarPhotometrics'][:,4]-subhalos['SubhaloStellarPhotometrics'][:,5]
#gas_frac = subhalos['SubhaloMassInRadType'][:,0]/(subhalos['SubhaloMassInRadType'][:,4]+subhalos['SubhaloMassInRadType'][:,0])
litte_h = 0.6774

mass=mass[data['gal_id']]/litte_h
g_r=g_r[data['gal_id']]  
#gas_frac = gas_frac[data['gal_id']]  
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
data = rfn.rec_append_fields(data, 'mass', mass  ,dtypes='f16')
data = rfn.rec_append_fields(data, 'g_r', g_r  ,dtypes='f16')
#data = rfn.rec_append_fields(data, 'gas_frac', gas_frac  ,dtypes='f16')
# Out:
# <style>.container { width:100% !important; }</style>
# Populating the interactive namespace from numpy and matplotlib
# /verafs/scratch/phy200017p/yjagvara/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['plotting', 'f', 'unique', 'spacing', 'test', 'array']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
data= data[log10(data['mass'])>10.0]

# %%
print(DataFrame(data[(data['gal_id']==372568)]))
#print(DataFrame(data[(data['gal_id']==632350)])) #&   (log10(data['mass'])<10.0)  &(log10(data['mass'])>9.0) ] ))
#print(data[(data['int_disk_counter_exp2']>0.1)]['gal_id'])
plt.figure(figsize=(5,5))
hist2d(data['int_disk_thin']+data['int_disk_thick'], data['mc_disk'],bins=50,norm=matplotlib.colors.LogNorm(), range = [[0, 1], [0, 1]])
x = np.linspace(0,1,10)
plot(x, x, lw=2,c='r')
#np.save('failed_ids_3ways.npy', data[(data['f_disk']==0.0)]['gal_id'])
# Out:
#    gal_id    f_disk  int_disk_thin  int_disk_thick  int_disk_counter_exp2  chisq_exp2  int_disk_exp1  int_disk_counter_exp1   chisq_exp1  mc_disk   pearson          mass       g_r
# 0  372568  0.436581       0.389272        0.340182           2.860751e-35  122.967818       0.596908           4.661527e-47  1898.861179  0.74448  0.202471  1.369319e+11  0.697638

# %%
# atlas_list=np.array([])
# for line in open('/home/yjagvara/atlas3d.dat', 'r'):
#     item = line.rstrip('\n') 
#     atlas_list = np.append(atlas_list, item)
# print(atlas_list)

atlas_data = np.loadtxt('/verafs/scratch/phy200017p/yjagvara/stuff_from_coma/atlas3d.dat' ,  delimiter=',')
sdss_data = np.loadtxt('/verafs/scratch/phy200017p/yjagvara/stuff_from_coma/sdss_dr7.dat' ,  delimiter=',')
rc3_data = np.loadtxt('/verafs/scratch/phy200017p/yjagvara/stuff_from_coma/conselice_rc3.dat' ,  delimiter=',')
sdss_gband_data = np.loadtxt('/verafs/scratch/phy200017p/yjagvara/stuff_from_coma/sdss_dr7_g-band.dat' ,  delimiter=',')

# %%
#h,bins=np.histogram(np.log10(filtered_mass),bins=15)
warnings.filterwarnings('ignore')

plt.figure(dpi=150)
bins=np.arange(8,12.5,0.25)

y=data['f_disk']
w=st.binned_statistic(np.log10(data['mass']), y, statistic=lambda y: sum(i>0.3 for i in y)/len(y),bins=bins )
plt.plot(w[1][:-1],w[0],'-o',label=' $\epsilon$-TNG100')

y=data['int_disk_thin'] +  data['int_disk_thick'] +data['int_disk_counter_exp2']
w=st.binned_statistic(np.log10(data['mass']), y, statistic=lambda y: sum(i>0.5 for i in y)/len(y),bins=bins )
plt.plot(w[1][:-1],w[0],'-o',color='red', label=r'1D $cos\alpha$-TNG100')

y=data['mc_disk']
w=st.binned_statistic(np.log10(data['mass']), y, statistic=lambda y: sum(i>0.5 for i in y)/len(y),bins=bins )
plt.plot(w[1][:-1],w[0],'-o',color='green', label='2D MC-TNG100')


#plt.plot(atlas_data[:,0], 1-atlas_data[:,1],color='black', label='ATLAS3D (median)')
#plt.plot(sdss_data[:,0], sdss_data[:,1],color='orange', label='sdss  (inferred mass)')
plt.plot(sdss_gband_data[:,0], sdss_gband_data[:,1],color='aqua', label='SDSS-dr7')

plt.plot(rc3_data[:,0], 1-rc3_data[:,1],color='magenta', label='RC-3')


plt.ylabel(r'$f_\mathrm{disk}$',fontsize = 22)
plt.xlabel('$\log{(M_*/M_\odot)}$', fontsize = 22)
#plt.title('TNG100-1')
plt.ylim(0,1)
plt.xlim(9,12.3)
plt.legend(loc=1)
print(sum( i > 12 for i in np.log10(data['mass'])))
#a#xvline(x=9)
plt.savefig('f_disk_at_mass.png', dpi=300,bbox_inches='tight')



plt.figure(figsize=(5,4))

h = hist2d(data['f_disk'],data['int_disk_thin'] +  data['int_disk_thick'],bins=50,norm=matplotlib.colors.LogNorm(), range = [[0, 1], [0, 1]])
x = np.linspace(0,1,10)
plot(x, x, lw=2,c='r')
ylabel('cos disk', fontsize = 16)
xlabel('eps disk', fontsize = 16)
axvline(0.1)
axhline(0.2)
colorbar()

plt.figure(figsize=(5,4))

h = hist2d(data['int_disk_thin'] +  data['int_disk_thick']+data['int_disk_counter_exp2'],data['mc_disk'],bins=50,norm=matplotlib.colors.LogNorm(), range = [[0, 1], [0, 1]])
x = np.linspace(0,1,10)
plot(x, x, lw=2,c='r')
xlabel('cos disk', fontsize = 16)
ylabel('mc disk', fontsize = 16)

colorbar()


#do this in mass bins,  10**9 cut
#converges for number of particles and how comp time converges. sample and see converges.
# get pearson r distribution for all galaxies
#think about the physical meaning of the correlat.
#f_disk vs mass  for different methods
# Out:
# 9

# %%
# look at cos vs js plot for the straggler population
# add shape measurement
# parameters from 2d fits vs number of particles, sampling convergenes
# bootstrap errors on f_disk vs mas plot
#3d plots include r, cos, js
#metalicity bulge vs halo star
#explore star particles' features

# %%
data= data[log10(data['mass'])>9.5]
bins=40

plt.figure(figsize=(5,4))
H, xedges, yedges = np.histogram2d(log10(data['mass']), data['f_disk'],bins=bins,  range = [[9.5, 12.5], [0, 1]])
H_norm_cols = H.T  
ylabel('eps disk', fontsize = 16)
xlabel('mass', fontsize = 16)
pc=plt.pcolormesh(xedges,yedges,H_norm_cols ,norm=matplotlib.colors.LogNorm())
colorbar(pc)
y=data['f_disk']
w=st.binned_statistic(np.log10(data['mass']), y, statistic=lambda y: sum(i>0.4 for i in y)/len(y),bins=bins )
plt.plot(w[1][:-1],w[0] ,color='orange', label='2d mc frac')

w=st.binned_statistic(np.log10(data['mass']), y, statistic='median',bins=bins )
plt.plot(w[1][:-1],w[0] ,color='red', label='2d mc med')
plt.show()


plt.figure(figsize=(5,4))
H, xedges, yedges = np.histogram2d(log10(data['mass']), data['int_disk_thin'] +  data['int_disk_thick'],bins=bins,  range = [[9.5, 12.5], [0, 1]])
H_norm_cols = H.T  
ylabel('cos disk', fontsize = 16)
xlabel('mass', fontsize = 16)
pc=plt.pcolormesh(xedges,yedges,H_norm_cols ,norm=matplotlib.colors.LogNorm())
colorbar(pc)
y=data['int_disk_thin'] +  data['int_disk_thick']
w=st.binned_statistic(np.log10(data['mass']), y, statistic=lambda y: sum(i>0.4 for i in y)/len(y),bins=bins )
plt.plot(w[1][:-1],w[0] ,color='orange', label='2d mc frac')

w=st.binned_statistic(np.log10(data['mass']), y, statistic='median',bins=bins )
plt.plot(w[1][:-1],w[0] ,color='red', label='2d mc med')
plt.show()

plt.figure(figsize=(5,4))
H, xedges, yedges = np.histogram2d(log10(data['mass']), data['mc_disk'],bins=bins,  range = [[9.5, 12.5], [0, 1]])
H_norm_cols = H.T  
ylabel('mc disk', fontsize = 16)
xlabel('mass', fontsize = 16)
pc=plt.pcolormesh(xedges,yedges,H_norm_cols ,norm=matplotlib.colors.LogNorm())
colorbar(pc)
y=data['mc_disk']
w=st.binned_statistic(np.log10(data['mass']), y, statistic=lambda y: sum(i>0.4 for i in y)/len(y),bins=bins )
plt.plot(w[1][:-1],w[0] ,color='orange', label='2d mc frac')

w=st.binned_statistic(np.log10(data['mass']), y, statistic='median',bins=bins )
plt.plot(w[1][:-1],w[0],color='red', label='2d mc med')
plt.show()

# %%
bins=30
plt.figure(figsize=(5,4))

H, xedges, yedges = np.histogram2d(log10(data['mass']), data['f_disk'],bins=bins,  range = [[9.5, 12.5], [0, 1]])
H_norm_cols = H.T / H.T.sum(axis=0, keepdims=True)
ylabel('eps disk', fontsize = 16)
xlabel('mass', fontsize = 16)
pc=plt.pcolormesh(xedges,yedges,H_norm_cols ,norm=matplotlib.colors.LogNorm())
colorbar(pc)
plt.show()
 

plt.figure(figsize=(5,4))

H, xedges, yedges = np.histogram2d(log10(data['mass']), data['int_disk_thin'] +  data['int_disk_thick'],bins=bins,  range = [[9.5, 12.5], [0, 1]])
H_norm_cols = H.T / H.T.sum(axis=0, keepdims=True)
ylabel('cos disk', fontsize = 16)
xlabel('mass', fontsize = 16)
pc=plt.pcolormesh(xedges,yedges,H_norm_cols ,norm=matplotlib.colors.LogNorm())
colorbar(pc)
plt.show()

plt.figure(figsize=(5,4))

H, xedges, yedges = np.histogram2d(log10(data['mass']), data['mc_disk'],bins=bins,  range = [[9.5, 12.5], [0, 1]])
H_norm_cols = H.T / H.T.sum(axis=0, keepdims=True)
ylabel('mc disk', fontsize = 16)
xlabel('mass', fontsize = 16)
pc=plt.pcolormesh(xedges,yedges,H_norm_cols ,norm=matplotlib.colors.LogNorm())
colorbar(pc)
plt.show()

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins,  range = [[10, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='summer',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    w=st.binned_statistic(mass, y, statistic=lambda y: sum(i>0.3 for i in y)/len(y),bins=bins )
    #ax.plot(w[1][:-1],w[0] ,color='orange', label='BTR<0.7')

    w=st.binned_statistic(mass, y, statistic='median',bins=bins )
    ax.plot(w[1][:-1],w[0] ,color='red', lw=4,label='Median')
    
    ax.set_xlim(10,12.5)
    ax.legend(fontsize=26)
    ax.set_ylim(0,1)
    ax.set_ylabel(r'$f^\mathrm{\, disc}_\mathrm{\epsilon}$', fontsize = 42)
    ax.set_xlabel('$\log{(M_*/M_\odot)}$', fontsize = 42)
    ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
    ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
    ax.set_xticklabels([10,10.5,11,11.5,12], fontsize = 26)
    colorbar(pc).ax.tick_params(labelsize=26)
    

    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    #ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
     
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 26)
    ax_histx.yaxis.tick_right()
    ax.axhline(0.3,color='blue', ls= '--',lw=4)
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 26)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)
data_mass = data[log10(data['mass'])>10]

fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)
#plt.rcParams["mathtext.fontset"] = "cm"
# use the previously defined function
scatter_hist(log10(data_mass['mass']) , data_mass['f_disk'], ax, ax_histx, ax_histy)
plt.savefig('f_eps_vs_mass.png', dpi=300,bbox_inches='tight')

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins,  range = [[10, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='summer',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    w=st.binned_statistic(mass, y, statistic=lambda y: sum(i>0.5 for i in y)/len(y),bins=bins )
    #ax.plot(w[1][:-1],w[0] ,color='orange', label='BTR<0.5')

    w=st.binned_statistic(mass, y, statistic='median',bins=bins )
    ax.plot(w[1][:-1],w[0] ,color='red', label='Median',lw=4)
    
    ax.set_xlim(10,12.5)
    ax.legend(fontsize=26)
    ax.set_ylim(0,1)
    ax.set_ylabel(r'$f^\mathrm{\, disc}_\mathrm{cos\alpha}$', fontsize = 42)
    ax.set_xlabel('$\log{(M_*/M_\odot)}$', fontsize = 42)
    ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
    ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
    ax.set_xticklabels([10,10.5,11,11.5,12], fontsize = 26)
    colorbar(pc).ax.tick_params(labelsize=26)
    
    ax.axhline(0.5,color='blue', ls= '--',lw=4)
    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    #ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
     
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 26)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 26)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)

# use the previously defined function
scatter_hist(log10(data_mass['mass']) , data_mass['int_disk_thin'] +  data_mass['int_disk_thick'], ax, ax_histx, ax_histy)
plt.savefig('f_cos_vs_mass.png', dpi=300,bbox_inches='tight')

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins,  range = [[10, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='summer',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    w=st.binned_statistic(mass, y, statistic=lambda y: sum(i>0.5 for i in y)/len(y),bins=bins )
    #ax.plot(w[1][:-1],w[0] ,color='orange', label='BTR<0.5')

    w=st.binned_statistic(mass, y, statistic='median',bins=bins )
    ax.plot(w[1][:-1],w[0] ,color='red', label='Median',lw=4)
    
    ax.set_xlim(10,12.5)
    ax.legend(fontsize=26)
    ax.set_ylim(0,1)
    ax.set_ylabel(r'$f^\mathrm{\, disc}_\mathrm{2D}$', fontsize = 42)
    ax.set_xlabel('$\log{(M_*/M_\odot)}$', fontsize = 42)
    ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
    ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
    ax.set_xticklabels([10,10.5,11,11.5,12], fontsize = 26)
    colorbar(pc).ax.tick_params(labelsize=26)
    ax.axhline(0.5,color='blue', ls= '--',lw=4)

    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    #ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 26)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 26)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)

import matplotlib

matplotlib.mathtext.SHRINK_FACTOR = 0.4
matplotlib.mathtext.GROW_FACTOR = 1 / 0.5
matplotlib.mathtext.DejaVuSansFontConstants.sup1 = 0.9  # default 0.5

fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)

# use the previously defined function
scatter_hist(log10(data_mass['mass']) , data_mass['mc_disk'], ax, ax_histx, ax_histy)
plt.savefig('f_mc_vs_mass.png', dpi=300,bbox_inches='tight')

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy,disk_color, ellip_color):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d( frac,mass,bins=bins,  range = [[0,1], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='summer',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    
    ax.set_xlim(0,1)
    #ax.legend(fontsize=15)
    ax.set_ylim(0,1)
    ax.axhline(0.5,color='blue', ls= '--',lw=4)
    ax.set_xlabel(r'$g-r$', fontsize = 42)
    ax.set_ylabel('$f^\mathrm{\, disc}_\mathrm{2D}$', fontsize = 42)
#     ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
#     ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
#     ax.set_xticklabels([9.5,10,10.5,11,11.5,12,12.5], fontsize = 26)
    colorbar(pc).ax.tick_params(labelsize=26)
    
    ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
    ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
    ax.set_xticklabels([0,0.2,0.4,0.6,0.8,], fontsize = 26)

    

    ax_histy.hist(mass, bins=bins,color='orange',alpha=0.5,density=True ,orientation='horizontal')
    #ax_histx.legend(fontsize=15)
    
    ax_histx.hist(frac, bins=bins, color='orange',density=False,histtype='step',label='total' )
    ax_histx.hist(disk_color, bins=bins, color='blue',density=False ,histtype='step',label='disk')
    ax_histx.hist(ellip_color, bins=bins, color='red',density=False ,histtype='step',label='bulge')
    ax_histx.legend(fontsize=18,loc=2)
    ax_histx.set_yticks([0, 400,700])
    ax_histx.set_yticklabels([0,  400,700], fontsize = 26)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([1,2,3])
    ax_histy.set_xticklabels([1,2,3], fontsize = 26)
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)
data_mass = data[log10(data['mass'])>9.5]
# use the previously defined function
disk_color_data = data_mass[data_mass['mc_disk']>0.5]['g_r']
ellip_color_data = data_mass[data_mass['mc_disk']<0.5]['g_r']

scatter_hist(data_mass['mc_disk'] , data_mass['g_r'], ax, ax_histx, ax_histy, disk_color_data, ellip_color_data)
plt.savefig('g_r_vs_f_mc.png', dpi=300,bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10, 10))
hist2d(data_mass['mc_disk'], data_mass['int_disk_thin'] +  data_mass['int_disk_thick'],norm=matplotlib.colors.LogNorm() , bins=90  )
plt.plot([0.,1.],[0.,1.], '-', color='black', lw=1)

# %%
data_mass = data[log10(data['mass'])>10]
plt.figure(figsize=(5,4))
h=hist((data_mass['f_disk'] ),bins=50 )
xlabel('f disk',fontsize = 16 )
ylabel('Count', fontsize = 16)

plt.figure(figsize=(5,4))
h=hist((data_mass['int_disk_thin'] +  data_mass['int_disk_thick'] ),bins=50 )
xlabel('cos disk',fontsize = 16 )
ylabel('Count', fontsize = 16)

plt.figure(figsize=(5,4))
h=hist((data_mass['mc_disk'] ),bins=50 )
xlabel('mc disk',fontsize = 16 )
ylabel('Count', fontsize = 16)
# Out:
# Text(0, 0.5, 'Count')

# %%
data_mass = data[log10(data['mass'])<13]
print(data_mass)
plt.figure(figsize=(5,4))
h=hist((data_mass['f_disk'] ),bins=200 )
xlabel('f disk',fontsize = 16 )
ylabel('Count', fontsize = 16)

plt.figure(figsize=(5,4))
h=hist((data['int_disk_thin'] +  data['int_disk_thick']),bins=200 )
xlabel('cos disk',fontsize = 16 )
ylabel('Count', fontsize = 16)

plt.figure(figsize=(5,4))
h=hist((data_mass['mc_disk'] ),bins=200 )
xlabel('mc disk',fontsize = 16 )
ylabel('Count', fontsize = 16)
# Out:
# [(     0, 0.10218692, 2.63201466e-02, 1.89137867e-01, 8.30437571e-02,  50.74619091, 2.08240277e-01, 8.21124388e-02,  51.01245637, 0.19524973, 2.        , 2.41857415e+12, 0.7495594 , 0.32842749)
#  (     1, 0.06560502, 3.17672365e-16, 2.95462000e-14, 1.95091538e-02, 238.36151652, 3.74927086e-15, 1.95091538e-02, 238.36151652, 0.        , 2.        , 3.79849635e+11, 0.735672  , 0.04003082)
#  (     2, 0.09128462, 3.32113804e-03, 1.81892149e-01, 9.74603350e-02,  50.21284191, 1.77860531e-01, 9.31638131e-02,  50.89841074, 0.17307073, 2.        , 4.25932659e+11, 0.57115555, 0.08927748)
#  ...
#  (704187, 0.30375937, 3.99737293e-02, 6.09904973e-01, 5.82744633e-23,  74.42240113, 6.44078406e-01, 1.24120925e-13,  77.65405002, 0.66753583, 0.10662088, 4.46359950e+09, 0.74620438, 0.04246903)
#  (719337, 0.29693756, 2.92185364e-02, 7.25572622e-01, 5.88761956e-17,  87.26143851, 7.48014962e-01, 7.78123219e-13,  90.52778176, 0.7388128 , 0.07935054, 5.24248324e+09, 0.72153282, 0.        )
# ...

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins)#,  range = [[9.5, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='viridis',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    
#     ax.set_xlim(9.5,12.5)
    ax.legend(fontsize=15)
    #ax.set_ylim(-1,1)
    ax.set_ylabel(r'$g-r$', fontsize = 42)
    ax.set_xlabel('$log_{10}$($M_{\odot}$)', fontsize = 42)
#     ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
#     ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
#     ax.set_xticklabels([9.5,10,10.5,11,11.5,12,12.5], fontsize = 26)
    colorbar(pc)
    

    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
     
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 16)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 16)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)
data_mass = data[log10(data['mass'])>9.5]
# use the previously defined function
scatter_hist(log10(data_mass['mass']) , data_mass['g_r'], ax, ax_histx, ax_histy)
#plt.savefig('mc_disk_only.png', dpi=300,bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=30
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins)#,  range = [[9.5, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='viridis',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)

    
#     ax.set_xlim(9.5,12.5)
    ax.legend(fontsize=15)
    #ax.set_ylim(-1,1)
    ax.set_xlabel(r'$f^{star}_{\epsilon}$', fontsize = 42)
    ax.set_ylabel('gas frac.', fontsize = 42)
#     ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
#     ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
#     ax.set_xticklabels([9.5,10,10.5,11,11.5,12,12.5], fontsize = 26)
    colorbar(pc)
    

    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
     
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 16)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 16)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)
data_mass = data[log10(data['mass'])>9.5]
# use the previously defined function
scatter_hist(data_mass['mc_disk'] , log10(data_mass['gas_frac']+1), ax, ax_histx, ax_histy)
#plt.savefig('mc_disk_only.png', dpi=300,bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
red_data = data_mass[data_mass['g_r']>0.6]
blue_data = data_mass[data_mass['g_r']<0.6]
plt.figure(figsize=(5,4))
h=hist((red_data['mc_disk'] ),bins=30 )
xlabel('mc disk',fontsize = 16 )
ylabel('Count', fontsize = 16)

plt.figure(figsize=(5,4))
h=hist((blue_data['mc_disk'] ),bins=30 )
xlabel('mc disk',fontsize = 16 )
ylabel('Count', fontsize = 16)
# Out:
# Text(0, 0.5, 'Count')

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins)#,  range = [[9.5, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='viridis',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    
#     ax.set_xlim(9.5,12.5)
    ax.legend(fontsize=15)
    #ax.set_ylim(-1,1)
    ax.set_ylabel(r'$g-r$', fontsize = 42)
    ax.set_xlabel('$log_{10}$($M_{\odot}$)', fontsize = 42)
#     ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
#     ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
#     ax.set_xticklabels([9.5,10,10.5,11,11.5,12,12.5], fontsize = 26)
    colorbar(pc)
    

    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
     
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 16)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 16)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)
data_mass = data[log10(data['mass'])>9.5]
# use the previously defined function
scatter_hist(log10(blue_data['mass']) , blue_data['mc_disk'], ax, ax_histx, ax_histy)
#plt.savefig('mc_disk_only.png', dpi=300,bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins)#,  range = [[9.5, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='viridis',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    
#     ax.set_xlim(9.5,12.5)
    ax.legend(fontsize=15)
    #ax.set_ylim(-1,1)
    ax.set_ylabel(r'$g-r$', fontsize = 42)
    ax.set_xlabel('$log_{10}$($M_{\odot}$)', fontsize = 42)
#     ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
#     ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
#     ax.set_xticklabels([9.5,10,10.5,11,11.5,12,12.5], fontsize = 26)
    colorbar(pc)
    

    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
     
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 16)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 16)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)
data_mass = data[log10(data['mass'])>9.5]
# use the previously defined function
scatter_hist(log10(red_data['mass']) , red_data['mc_disk'], ax, ax_histx, ax_histy)
#plt.savefig('mc_disk_only.png', dpi=300,bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(5,4))
h=hist((data_mass['pearson']),bins=100)
xlabel(' Pearson r',fontsize = 16 )
ylabel('Count', fontsize = 16)
plt.figure(figsize=(5,4))

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins)#,  range = [[9.5, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='viridis',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    
#     ax.set_xlim(9.5,12.5)
    #ax.legend(fontsize=15)
    #ax.set_ylim(-1,1)
    ax.set_ylabel(r'$f_{thin}^{star}$', fontsize = 42)
    ax.set_xlabel(r'$f_{thick}^{star}$', fontsize = 42)
#     ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
#     ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
#     ax.set_xticklabels([9.5,10,10.5,11,11.5,12,12.5], fontsize = 26)
    colorbar(pc)
    

    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    #ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
     
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 16)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 16)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)
data_mass = data[log10(data['mass'])>9.5]
# use the previously defined function
scatter_hist( (data_mass['int_disk_thick']), (data_mass['int_disk_thin']) , ax, ax_histx, ax_histy)
#plt.savefig('mc_disk_only.png', dpi=300,bbox_inches='tight')

# %%
def scatter_hist(mass, frac, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    bins=40
    H, xedges, yedges = np.histogram2d(mass, frac,bins=bins)#,  range = [[9.5, 12.5], [0, 1]])
    H_norm_cols = H.T  
    pc=ax.pcolormesh(xedges,yedges,H_norm_cols ,cmap='viridis',norm=matplotlib.colors.LogNorm())
    #colorbar(pc)
    y=frac
    
#     ax.set_xlim(9.5,12.5)
    #ax.legend(fontsize=15)
    #ax.set_ylim(-1,1)
    ax.set_ylabel(r'$f_{thin}^{star}$', fontsize = 42)
    ax.set_xlabel(r'$f_{thick}^{star}$', fontsize = 42)
#     ax.set_yticks([ 0,0.2,0.4,0.6,0.8,1])
#     ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1], fontsize = 26)
#     ax.set_xticklabels([9.5,10,10.5,11,11.5,12,12.5], fontsize = 26)
    colorbar(pc)
    

    ax_histx.hist(mass, bins=bins,color='orange',alpha=0.5,density=True )
    #ax_histx.legend(fontsize=15)
    
    ax_histy.hist(frac, bins=bins, color='orange',alpha=0.5,orientation='horizontal',density=True )
     
    ax_histx.set_yticks([0,0.5,1,1.5])
    ax_histx.set_yticklabels([0,0.5,1,1.5], fontsize = 16)
    ax_histx.yaxis.tick_right()
    
    ax_histy.set_xticks([0,1,2,3])
    ax_histy.set_xticklabels([0,1,2,3], fontsize = 16)
    #ax_histy.yaxis.tick_right()
 
 
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a square Figureplt.subplot(2,4,1)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes(rect_scatter)
ax_histx = fig.add_axes(rect_histx, sharex=ax)
ax_histy = fig.add_axes(rect_histy, sharey=ax)
data_mass = data[log10(data['mass'])>9.5]
data_thin = data_mass[(data_mass['int_disk_thin'])<0.15]
# use the previously defined function
scatter_hist((data_thin['int_disk_thin']) , data_thin['int_disk_thick'], ax, ax_histx, ax_histy)
#plt.savefig('mc_disk_only.png', dpi=300,bbox_inches='tight')

# %%
hist(log10(straggler['mass']),bins=20)
xlim(8.5,12)
ylim(0,150)
plt.xlabel('$log_{10}$( $h^{-1}$ $M_{\odot}$)')
ylabel('Number of galaxies')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b21ad6a4fe30> in <module>
# ----> 1 hist(log10(straggler['mass']),bins=20)
#       2 xlim(8.5,12)
#       3 ylim(0,150)
#       4 plt.xlabel('$log_{10}$( $h^{-1}$ $M_{\odot}$)')
#       5 ylabel('Number of galaxies')
#
# NameError: name 'straggler' is not defined

# %%
hist(log10(data['mass']),bins=20)
xlim(8.5,12)

# %%
print(DataFrame(data[ (data['mc_disk']<0.5)   & (log10(data['mass'])<11)] ))
print(data[ (data['mc_disk']>0.5)   & (log10(data['mass'])<11.2)   & (log10(data['mass'])>10.9)]['gal_id'])
